# %%
import numpy as np
import pandas as pd

# %%
df_cancer = pd.read_csv('Cancer_Data.csv')

# %%
# df_cancer.[df_cancer['diagnosis'] == 'B']

df_cancer.loc[df_cancer['diagnosis'] == 'B', 'id'].count()
# Out:
# 357

# %%
df_cancer['diagnosis'] = df_cancer['diagnosis'].str.replace('B', 'benign cancer').replace('M', 'malignant cancer')
df_cancer['diagnosis'].value_counts()
# Out:
# diagnosis
# benign cancer       357
# malignant cancer    212
# Name: count, dtype: int64

# %%
df_cancer.head()
# Out:
#          id         diagnosis  radius_mean  texture_mean  perimeter_mean  \
# 0    842302  malignant cancer        17.99         10.38          122.80
# 1    842517  malignant cancer        20.57         17.77          132.90
# 2  84300903  malignant cancer        19.69         21.25          130.00
# 3  84348301  malignant cancer        11.42         20.38           77.58
# 4  84358402  malignant cancer        20.29         14.34          135.10
#
#    area_mean  smoothness_mean  compactness_mean  concavity_mean  \
# 0     1001.0          0.11840           0.27760          0.3001
# 1     1326.0          0.08474           0.07864          0.0869
# 2     1203.0          0.10960           0.15990          0.1974
# 3      386.1          0.14250           0.28390          0.2414
# 4     1297.0          0.10030           0.13280          0.1980
#
#    concave points_mean  ...  texture_worst  perimeter_worst  area_worst  \
# ...

# %%
df_cancer[(df_cancer['diagnosis']=='malignant cancer')&(df_cancer['radius_mean']>25)]
# Out:
#             id         diagnosis  radius_mean  texture_mean  perimeter_mean  \
# 82     8611555  malignant cancer        25.22         24.91           171.5
# 180     873592  malignant cancer        27.22         21.87           182.1
# 212    8810703  malignant cancer        28.11         18.47           188.5
# 352     899987  malignant cancer        25.73         17.46           174.2
# 461  911296202  malignant cancer        27.42         26.27           186.9
#
#      area_mean  smoothness_mean  compactness_mean  concavity_mean  \
# 82      1878.0           0.1063            0.2665          0.3339
# 180     2250.0           0.1094            0.1914          0.2871
# 212     2499.0           0.1142            0.1516          0.3201
# 352     2010.0           0.1149            0.2363          0.3368
# 461     2501.0           0.1084            0.1988          0.3635
#
#      concave points_mean  ...  texture_worst  perimeter_worst  area_worst  \
# ...
